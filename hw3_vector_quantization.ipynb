# %% [markdown]
# <a href="https://colab.research.google.com/github/igor531205/applied_machine_learning_tasks/blob/hw3_vector_quantization/hw3_vector_quantization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing libraries

# %%
# !pip install -U -q transformers datasets

# %% [markdown]
# Standard libraries

# %%
import numpy as np
import pandas as pd
import torch
from statistics import mean

# %% [markdown]
# Datasets

# %%
from datasets import load_dataset

# %% [markdown]
# Models

# %%
from transformers import BertTokenizer, BertModel
from sklearn.cluster import KMeans

# %% [markdown]
# # Product Quantization

# %% [markdown]
# Function receiving tokens

# %%
def get_tokens(text):
    """Function receiving tokens"""
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy().astype(np.float64)

# %% [markdown]
# Function to quantize vector

# %%
def quantize_vector(vector):
    """Function vector quantization"""
    quantized = []
    for i in range(4):
        sub_vec = vector[i*sub_vector_size:(i+1)*sub_vector_size]
        cluster_index = kmeans_models[i].predict([sub_vec])[0]
        quantized.append(cluster_index)
    return quantized

# %% [markdown]
# Function to reconstruct vector

# %%
def reconstruct_vector(quantized):
    """Function reconstruction vector"""
    reconstructed = []
    for i, index in enumerate(quantized):
        reconstructed.append(codebooks[i][index])
    return np.concatenate(reconstructed)

# %% [markdown]
# Functions to compute errors

# %%
def absolute_error(original, reconstructed):
    """Function absolute error"""
    return np.linalg.norm(original - reconstructed)

def relative_error(original, reconstructed):
    """Function relative error"""
    return np.linalg.norm(original - reconstructed) / np.linalg.norm(original)

# %% [markdown]
# Load IMDb dataset from [Hugging Face Hub](https://huggingface.co/docs/datasets/v1.18.2/load_hub.html?highlight=imdb)

# %%
dataset = load_dataset("imdb", split="train[:10000]", token=False)
# Out:
# README.md:   0%|          | 0.00/7.81k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# unsupervised-00000-of-00001.parquet:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %% [markdown]
# Load BERT model and tokenizer

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', clean_up_tokenization_spaces=False)
model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %% [markdown]
# Get tokens from dataset

# %%
tokens = np.array([get_tokens(text) for text in dataset['text']])

# %% [markdown]
# Split each vector into 4 sub-vectors

# %%
sub_vector_size = tokens.shape[1] // 4
sub_vectors = [tokens[:, i*sub_vector_size:(i+1)*sub_vector_size] for i in range(4)]

# %% [markdown]
# Cluster each sub-vector space

# %%
kmeans_models = []
codebooks = []
for i, sub_vector in enumerate(sub_vectors):
    kmeans = KMeans(n_clusters=16, random_state=42)
    kmeans.fit(sub_vector)
    kmeans_models.append(kmeans)
    codebooks.append(kmeans.cluster_centers_)

# %%
data = []
for i in range(len(tokens)):
    original = tokens[i]
    quantized = quantize_vector(original)
    reconstructed = reconstruct_vector(quantized)
    abs_error = absolute_error(original, reconstructed)
    rel_error = relative_error(original, reconstructed)
    vector_data = {
        'Vector_Index': i,
        'Quantized_Indices': quantized,
        'Original_Vector': mean(original),
        'Reconstructed_Vector': mean(reconstructed),
        'Absolute_Error': abs_error,
        'Relative_Error': rel_error
    }
    data.append(vector_data)

pd.DataFrame(data)
# Out:
#       Vector_Index Quantized_Indices  Original_Vector  Reconstructed_Vector  \
# 0                0     [1, 10, 8, 4]        -0.013060             -0.012449
# 1                1    [6, 9, 11, 13]        -0.013599             -0.013005
# 2                2    [6, 2, 10, 12]        -0.014038             -0.014517
# 3                3     [9, 3, 8, 13]        -0.013222             -0.013099
# 4                4    [11, 4, 3, 12]        -0.013512             -0.014906
# ...            ...               ...              ...                   ...
# 9995          9995  [11, 15, 10, 12]        -0.015476             -0.014203
# 9996          9996      [3, 8, 1, 6]        -0.012354             -0.012113
# 9997          9997     [7, 7, 15, 1]        -0.013585             -0.014414
# 9998          9998     [7, 10, 2, 1]        -0.013223             -0.014911
# 9999          9999     [5, 11, 1, 7]        -0.012349             -0.011235
#
#       Absolute_Error  Relative_Error
# 0           1.999209        0.257449
# 1           2.755848        0.334430
# 2           3.023846        0.371386
# 3           2.550707        0.320993
# 4           2.370013        0.307747
# ...              ...             ...
# 9995        2.429611        0.298753
# 9996        2.386514        0.291047
# 9997        2.935955        0.367882
# 9998        1.839239        0.240572
# 9999        2.599676        0.312507
#
# [10000 rows x 6 columns]

# %%
num_codebooks = 3
print("Codebooks:")
for i, codebook in enumerate(codebooks[:num_codebooks]):
    codebook_df = pd.DataFrame(codebook, columns=[f'Component_{j}' for j in range(codebook.shape[1])])
    print(f"Subspace {i} codebook:\n{codebook_df.head()}")
    print()
# Out:
# Codebooks:
# Subspace 0 codebook:
#    Component_0  Component_1  Component_2  Component_3  Component_4  \
# 0    -0.123971    -0.000825     0.153507    -0.059117     0.268319
# 1    -0.017809     0.147999     0.159545    -0.055919     0.154731
# 2     0.037209     0.079063     0.171876    -0.027905     0.210179
# 3     0.128692     0.086029     0.201520    -0.034690     0.162486
# 4    -0.086777    -0.024903     0.247149    -0.048851     0.272943
#
#    Component_5  Component_6  Component_7  Component_8  Component_9  ...  \
# 0    -0.037508     0.069039     0.545046     0.078734    -0.086820  ...
# 1    -0.064150     0.132728     0.636008     0.096023    -0.131347  ...
# 2    -0.060985     0.064872     0.542210     0.203767    -0.054786  ...
# 3    -0.119507     0.136100     0.728353     0.086460    -0.091128  ...
# 4    -0.141947     0.092434     0.598652     0.068393    -0.179315  ...
#
#    Component_182  Component_183  Component_184  Component_185  Component_186  \
# 0       0.119809       0.015523       0.153984      -0.204698       0.040469
# 1       0.068096       0.005145       0.111406      -0.238707       0.082960
# 2       0.138143       0.001026       0.019943      -0.271769       0.041949
# 3       0.109182       0.123933       0.090260      -0.210624       0.198179
# 4       0.002930       0.108217       0.111627      -0.158256       0.096186
#
#    Component_187  Component_188  Component_189  Component_190  Component_191
# 0      -0.299296       0.033422      -0.070139      -0.227275      -0.146993
# 1      -0.247625       0.101827      -0.058595      -0.323829      -0.230884
# 2      -0.293016      -0.022634      -0.027102      -0.307765      -0.122581
# 3      -0.252475       0.036689      -0.032557      -0.337690      -0.183882
# 4      -0.197755       0.117649      -0.106022      -0.205770      -0.109956
#
# [5 rows x 192 columns]
#
# Subspace 1 codebook:
#    Component_0  Component_1  Component_2  Component_3  Component_4  \
# 0    -0.278799    -0.197634     0.191541    -0.226381    -0.061469
# 1    -0.276551    -0.139050     0.292550    -0.387362    -0.101070
# 2    -0.261784    -0.186068     0.217747    -0.236845    -0.153576
# 3    -0.254224    -0.208744     0.190620    -0.297933    -0.120008
# 4    -0.267618    -0.109331     0.194847    -0.257703    -0.175021
#
#    Component_5  Component_6  Component_7  Component_8  Component_9  ...  \
# 0    -0.264367    -0.378961    -0.104845    -0.009213     0.070373  ...
# 1    -0.227392    -0.371069     0.042312    -0.036846     0.119800  ...
# 2    -0.140420    -0.397727    -0.073883     0.034812     0.125863  ...
# 3    -0.137640    -0.382381    -0.050922    -0.033212     0.075231  ...
# 4    -0.219740    -0.373425    -0.089229    -0.040871     0.118907  ...
#
#    Component_182  Component_183  Component_184  Component_185  Component_186  \
# 0      -0.398819      -0.077042       0.078821       0.094792      -0.129291
# 1      -0.236426      -0.167004       0.090444       0.081089      -0.137078
# 2      -0.426709      -0.070533       0.050888       0.066770      -0.161603
# 3      -0.422698      -0.089356       0.082949       0.102993      -0.165348
# 4      -0.449916      -0.102303       0.067302       0.034229      -0.230028
#
#    Component_187  Component_188  Component_189  Component_190  Component_191
# 0       0.160454      -0.294791      -0.459583       0.053458      -0.218302
# 1       0.094579      -0.285144      -0.518689       0.005008      -0.073137
# 2       0.293999      -0.389877      -0.269837       0.107807      -0.314116
# 3       0.236354      -0.353137      -0.408228       0.051361      -0.222476
# 4       0.316754      -0.374844      -0.264872       0.100906      -0.288989
#
# [5 rows x 192 columns]
#
# Subspace 2 codebook:
#    Component_0  Component_1  Component_2  Component_3  Component_4  \
# 0     0.065680    -0.117772    -0.045789    -0.093362    -0.117373
# 1    -0.010842    -0.071818    -0.033746    -0.050666    -0.147078
# 2     0.003009    -0.111775    -0.030464    -0.038759    -0.141496
# 3     0.099223    -0.150618    -0.022659    -0.062029    -0.129306
# 4     0.222544    -0.132589    -0.018033    -0.181077    -0.097224
#
#    Component_5  Component_6  Component_7  Component_8  Component_9  ...  \
# 0    -0.379721     0.113808    -0.183911    -0.107448    -0.356881  ...
# 1    -0.324699     0.073123    -0.159832    -0.161050    -0.359995  ...
# 2    -0.394815     0.088198    -0.196520    -0.146243    -0.345312  ...
# 3    -0.395361     0.047890    -0.197215    -0.112045    -0.420956  ...
# 4    -0.387811     0.059262    -0.169475    -0.062008    -0.446916  ...
#
#    Component_182  Component_183  Component_184  Component_185  Component_186  \
# 0      -0.152155      -0.003469      -0.175908      -0.259338      -0.115773
# 1      -0.096299      -0.017006      -0.140522      -0.209571      -0.103747
# 2      -0.154053      -0.003867      -0.210317      -0.200014      -0.064755
# 3      -0.168868      -0.060261      -0.233045      -0.209737      -0.102958
# 4      -0.107298      -0.064393      -0.118456      -0.325243      -0.142890
#
#    Component_187  Component_188  Component_189  Component_190  Component_191
# 0      -0.005586       0.207848      -0.049745       0.034549       0.180025
# 1       0.010705       0.186325       0.009270       0.034616       0.198169
# 2       0.106503       0.246821      -0.030992       0.018528       0.263529
# 3       0.064943       0.242248      -0.074365      -0.035561       0.238380
# 4      -0.011618       0.298447      -0.113157      -0.053503       0.210524
#
# [5 rows x 192 columns]

# %%
total_abs_error = 0
total_rel_error = 0
for vec in tokens:
    quantized = quantize_vector(vec)
    reconstructed = reconstruct_vector(quantized)
    total_abs_error += absolute_error(vec, reconstructed)
    total_rel_error += relative_error(vec, reconstructed)

average_abs_error = total_abs_error / len(tokens)
average_rel_error = total_rel_error / len(tokens)
print(f"Average absolute error on the dataset: {average_abs_error}")
print(f"Average relative error on the dataset: {average_rel_error}")
# Out:
# Average absolute error on the dataset: 2.4475081558410485
# Average relative error on the dataset: 0.30320309683798974

# %% [markdown]
# Около 30% исходного вектора теряется во время восстановления
